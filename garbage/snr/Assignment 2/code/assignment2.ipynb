# %%
import pandas as pd
import math
# Out:
# 2.0

# %%
def cal_median(data):
    n=len(data)
    print("length is {}".format(n))
    data=list(data)
    data.sort()
    Median=-1
    if len(data)%2==1:
        Median=float(data[int(n/2)])
    else:
        pos1=int(n/2)
        pos2=int((n-1)/2)
        Median=(data[pos1]+data[pos2])/2
    return Median

# %%
def fun1(data):
#     print(data)
#     mean calculation
    Mean=0.0
    n=len(data)
    for val in data:
        Mean=Mean+val
    Mean/=n
    print("Mean:{}".format(Mean))
#     print(data.mean())
    
#     median calculation
    data=list(data)
    data.sort()
    Median=-1
    if len(data)%2==1:
        Median=float(data[int(n/2)])
    else:
        pos1=int(n/2)
        pos2=int((n-1)/2)
        Median=(data[pos1]+data[pos2])/2
    print("Median:{}".format(Median))
        
#     Mode calculation
    tmp={}
    for val in data:
        if val in tmp:
            tmp[val]=tmp[val]+1
        else:
            tmp[val]=1
    max_frequency=max(tmp.values())
    Modes=[]
#     print(tmp)
    for val in tmp.keys():
        if tmp[val]==max_frequency:
            Modes.append(val)
    if len(Modes)==len(data):
        print("Frequency of all values is same , So there is no mode in this case")
    else:
        print("Modes are as follows: ",end=" ")
        print(Modes)
    
#     Midrange
    print("Midrange:{}".format((min(data)+max(data))/2))
    
#     variance calculation
    Variance=0.0
    for val in data:
        Variance+=(val-Mean)*(val-Mean)/(n-1)
    print("Variance:{}".format(Variance))
    
#     Standard Deviation
    StandardDeviation=math.sqrt(Variance)
    print("StandardDeviation:{}".format(StandardDeviation))
    
#     Range
    Range=max(data)-min(data)
    print("Range:{}".format(Range))
    
#     quartiles
    Quartiles=[]
    Quartiles.append(cal_median(data)) # mid Quartiles
    Quartiles.append(cal_median(data[:int((n+1)/2)]))  # upper Quartiles
    Quartiles.append(cal_median(data[int((n+1)/2):]))  # lower Quartiles
    Quartiles.sort()
    print("Quartiles: ",end=" ")
    print(Quartiles)
    
#     interquartile range
    Interquartile_Range=max(Quartiles)-min(Quartiles)
    print("Interquartile_Range:{} ".format(Interquartile_Range))
    
#     five-number summary
    Five_Number_Summary=[]
    Five_Number_Summary.append(min(data)) # min value
    for val in Quartiles:  #quartiles
        Five_Number_Summary.append(val) 
    Five_Number_Summary.append(max(data)) #max value
    
    print("Five-Number Summary: ",end=" ")
    print(Five_Number_Summary)

# %%
fun1([1,3,3,1,5,10000])
# Out:
# Mean:1668.8333333333333
# Median:3.0
# Modes are as follows:  [1, 3]
# Midrange:5000.5
# Variance:16658003.366666663
# StandardDeviation:4081.4217334976133
# Range:9999
# length is 6
# length is 3
# length is 3
# Quartiles:  [1.0, 3.0, 5.0]
# Interquartile_Range:4.0
# Five-Number Summary:  [1, 1.0, 3.0, 5.0, 10000]

# %%
df = pd.read_csv (r'D:\abhishek\7th SEM\DM Lab\Assignment 2\breast-cancer-wisconsin.csv')   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
print(df.info())
for val in df:
    fun1(df[val])  # send entire columns this way
# print(df.loc[[0,1,2]])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sample code number           699 non-null    int64
#  1   Clump Thickness              699 non-null    int64
#  2   Uniformity of Cell Size      699 non-null    int64
#  3   Uniformity of Cell Shape     699 non-null    int64
#  4   Marginal Adhesion            699 non-null    int64
#  5   Single Epithelial Cell Size  699 non-null    int64
#  6   Bare Nuclei                  699 non-null    object
#  7   Bland Chromatin              699 non-null    int64
#  8   Normal Nucleoli              699 non-null    int64
#  9   Mitoses                      699 non-null    int64
#  10  Class                        699 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB
# None
# Mean:1071704.0987124464
# Median:1171710.0
# ...

# %%
print(df.to_string())
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0               1000025                5                        1                         1                  1                            2           1                3                1        1      2
# 1               1002945                5                        4                         4                  5                            7          10                3                2        1      2
# 2               1015425                3                        1                         1                  1                            2           2                3                1        1      2
# ...

# %%
print(df["Clump Thickness"].mean())
# Out:
# 4.417739628040057

# %%
# To find out mean
tmp=0.0
for val in df["Clump Thickness"]:
    tmp=tmp+val
print(tmp/699.0)
# Out:
# 4.417739628040057

# %%
print(df["Clump Thickness"].median())
# Out:
# 4.0

# %%
# median is middle value in sorted data
tmp=list(df["Clump Thickness"])
tmp.sort()
print(float(tmp[349]))
# Out:
# 4.0

# %%
print(list(df["Clump Thickness"].mode()))
# Out:
# [1]

# %%
# for mode calculati
tmp={}
for val in df["Clump Thickness"]:
    if val in tmp:
        tmp[val]=tmp[val]+1
    else:
        tmp[val]=1
max_frequency=(max(tmp.values()))
ans=[]
print(tmp)
for val in tmp.keys():
    if tmp[val]==max_frequency:
        ans.append(val)
print(ans)
# Out:
# {5: 130, 3: 108, 6: 34, 4: 80, 8: 46, 1: 145, 2: 50, 7: 23, 10: 69, 9: 14}
# [1]
